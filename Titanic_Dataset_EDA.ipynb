# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("titanic.csv")

# %%
df.shape
# Out:
# (418, 12)

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 191         1083         0       1
# 1            893         1       3
# 217         1109         0       1
# 179         1071         1       1
# 73           965         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 191                             Salomon, Mr. Abraham L    male   NaN      0
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 217                           Wick, Mr. George Dennick    male  57.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 73                     Ovies y Rodriguez, Mr. Servando    male  28.5      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 191      0    111163   26.0000   NaN        S
# 1        0    363272    7.0000   NaN        S
# 217      1     36928  164.8667   NaN        S
# 179      2  PC 17756   83.1583   E45        C
# 73       0  PC 17562   27.7208   D43        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_corelation=df.select_dtypes(include=[float, int]).corr()

# %%
df_corelation
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.023245 -0.026751 -0.034102  0.003818  0.043080
# Survived       -0.023245  1.000000 -0.108615 -0.000013  0.099943  0.159120
# Pclass         -0.026751 -0.108615  1.000000 -0.492143  0.001087  0.018721
# Age            -0.034102 -0.000013 -0.492143  1.000000 -0.091587 -0.061249
# SibSp           0.003818  0.099943  0.001087 -0.091587  1.000000  0.306895
# Parch           0.043080  0.159120  0.018721 -0.061249  0.306895  1.000000
# Fare            0.008211  0.191514 -0.577147  0.337932  0.171539  0.230046
#
#                  Fare
# PassengerId  0.008211
# Survived     0.191514
# Pclass      -0.577147
# Age          0.337932
# SibSp        0.171539
# Parch        0.230046
# Fare         1.000000

# %%
df[df['Fare'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 152         1044         0       3  Storey, Mr. Thomas  male  60.5      0
#
#      Parch Ticket  Fare Cabin Embarked
# 152      0   3701   NaN   NaN        S

# %%
df['Age']=df['Age'].fillna(30)

# %%
df['Age']=df['Age'].astype(int)

# %%
df['Fare']=df['Fare'].fillna(36)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    int64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         418 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 39.3+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex  Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male   34      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female   47      1      0
# 2                     Myles, Mr. Thomas Francis    male   62      0      0
# 3                              Wirz, Mr. Albert    male   27      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df_plot=df['Survived'].value_counts().plot(kind='bar', color='blue', label='Survived')

# %%
df['Pclass'].value_counts().plot(kind='bar', color='grey')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Sex'].value_counts().plot(kind='pie',labels=["Male", "Female"], autopct="%.2f", ylabel="Sex")
# Out:
# <Axes: ylabel='Sex'>

# %%
sns.histplot(df["Age"], bins=20, kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.scatterplot(data=df, x="Pclass", y="Fare")
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot(x=df["Fare"])
# Out:
# <Axes: xlabel='Fare'>

# %%
df.groupby("Sex")["Survived"].sum()
# Out:
# Sex
# female    152
# male        0
# Name: Survived, dtype: int64

# %%
sns.heatmap(data=df.select_dtypes(include=[float, int]).corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.displot(data=df, x="Age", hue="Survived", bins=20)

# %%
sns.barplot(data=df, x="Survived", y="Fare")
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
sns.barplot(data=df, x="Pclass", y="Fare")
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# Conclusion-
# 1. 152 Passenger survived i.e. of Sex=Female
# 2. No male Passenger Survived.
# 3. Max no passengers in Class 3 Min is in Class 2
# 4. No of Males= 63.64 and Females = 36.36
# 5. Most age group Passengers belongs to 20 - 30 age group and most survived passengers also beelongs to this age group only.
# 6.Passengers survived most paid higher fair and travelled in Class 1.
# 7. Least survival rate is in class 3.
